# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = np.linspace(1,200,200)
y1 = 1/x

# %%
plt.plot(x,y)

# %%
x2 = np.linspace(1,200,200)
y2 = np.zeros_like(x2)

for idx, value in enumerate(x2):
    if idx == 0:
        y2[idx] = 1
    else:
        y2[idx] = y[idx-1]/value

# %%
plt.plot(x1,y1, label = 'r(n) = 1/n')
plt.plot(x2,y2, label = 'r(n) = r(n-1)/n')

plt.title('Learning Rate vs. Iteration Number')
plt.ylabel('Learning Rate r(n)')
plt.xlabel('Iteration Number(n)')
plt.legend()

# %%
plt.plot(x1,y1, marker = '.', label = 'r(n) = 1/n')
plt.plot(x2,y2, marker = '.', label = 'r(n) = r(n-1)/n')

plt.title('Learning Rate vs. Iteration Number')
plt.ylabel('Learning Rate r(n)')
plt.xlabel('Iteration Number(n)')
plt.xlim(0,40)
plt.legend()
